# %% [markdown]
# # VectorSketch example 👨‍🔬
#
# The `VectorSketch` widget stores strokes as a set of lines.
# Drawing may feel smoother as you are not painting directly onto the canvas pixels.
# You can use `.svg` to extract the sketch's SVG representation.

# %%
# %pip install ipysketch_lite

# %%
from ipysketch_lite import VectorSketch

sketch = VectorSketch()

# %%
sketch.image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x300>

# %%
from IPython.display import display, SVG

display(SVG(sketch.svg))
